# %%
import pandas as pd

# %%
df = pd.read_csv('My_Free_WordStream_Keywords_1.csv')

# %%
import re

def tokenize(txt) :
  tokens = re.split('\W+', txt)
  return tokens

df['keyword_clean_tokenized'] = df['Keyword'].apply(lambda x: tokenize(x.lower()))

# %%
df.head(50)
# Out:
#                        Keyword  ...         keyword_clean_tokenized
# 0            digital marketing  ...            [digital, marketing]
# 1          affiliate marketing  ...          [affiliate, marketing]
# 2                   influencer  ...                    [influencer]
# 3       social media marketing  ...      [social, media, marketing]
# 4            network marketing  ...            [network, marketing]
# 5            inbound marketing  ...            [inbound, marketing]
# 6           marketing strategy  ...           [marketing, strategy]
# 7              email marketing  ...              [email, marketing]
# 8            content marketing  ...            [content, marketing]
# 9          market segmentation  ...          [market, segmentation]
# 10        marketing management  ...         [marketing, management]
# 11                segmentation  ...                  [segmentation]
# 12              marketing plan  ...               [marketing, plan]
# 13            online marketing  ...             [online, marketing]
# 14               ansoff matrix  ...                [ansoff, matrix]
# 15        influencer marketing  ...         [influencer, marketing]
# 16    digital marketing agency  ...    [digital, marketing, agency]
# 17             hubspot academy  ...              [hubspot, academy]
# 18               target market  ...                [target, market]
# 19              neuromarketing  ...                [neuromarketing]
# 20             lead generation  ...              [lead, generation]
# 21                brand equity  ...                 [brand, equity]
# 22             trade marketing  ...              [trade, marketing]
# 23          guerilla marketing  ...           [guerilla, marketing]
# 24               word of mouth  ...               [word, of, mouth]
# 25            direct marketing  ...             [direct, marketing]
# 26               philip kotler  ...                [philip, kotler]
# 27       multi level marketing  ...       [multi, level, marketing]
# 28             brand awareness  ...              [brand, awareness]
# 29             market analysis  ...              [market, analysis]
# 30                     martech  ...                       [martech]
# 31                niche market  ...                 [niche, market]
# 32               b2b marketing  ...                [b2b, marketing]
# 33       go to market strategy  ...      [go, to, market, strategy]
# 34         competitor analysis  ...          [competitor, analysis]
# 35       performance marketing  ...        [performance, marketing]
# 36            marketing agency  ...             [marketing, agency]
# 37               seo marketing  ...                [seo, marketing]
# 38            4ps of marketing  ...            [4ps, of, marketing]
# 39          facebook marketing  ...           [facebook, marketing]
# 40     search engine marketing  ...     [search, engine, marketing]
# 41            social marketing  ...             [social, marketing]
# 42                 e marketing  ...                  [e, marketing]
# 43   digital marketing company  ...   [digital, marketing, company]
# 44                  seo agency  ...                   [seo, agency]
# 45  digital marketing services  ...  [digital, marketing, services]
# 46          advertising agency  ...           [advertising, agency]
# 47    google digital marketing  ...    [google, digital, marketing]
# 48                    omnisend  ...                      [omnisend]
# 49          internet marketing  ...           [internet, marketing]
#
# [50 rows x 8 columns]
